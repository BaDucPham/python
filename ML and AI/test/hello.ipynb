# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 5)                 30
#
#  dense_4 (Dense)             (None, 5)                 30
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 2s 7ms/step - loss: 0.6920 - accuracy: 0.5861
# Epoch 2/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6883 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6810 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6643 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6388 - accuracy: 0.5861
# Epoch 6/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6084 - accuracy: 0.5861
# Epoch 7/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5884 - accuracy: 0.5861
# Epoch 8/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5758 - accuracy: 0.5861
# Epoch 9/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5695 - accuracy: 0.5861
# Epoch 10/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5654 - accuracy: 0.5861
# Epoch 11/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5616 - accuracy: 0.7572
# Epoch 12/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5582 - accuracy: 0.7871
# Epoch 13/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5553 - accuracy: 0.7835
# Epoch 14/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5526 - accuracy: 0.7859
# Epoch 15/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5504 - accuracy: 0.7859
# Epoch 16/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5481 - accuracy: 0.7871
# Epoch 17/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5466 - accuracy: 0.7847
# Epoch 18/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5444 - accuracy: 0.7883
# Epoch 19/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5423 - accuracy: 0.7907
# Epoch 20/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5407 - accuracy: 0.7883
# Epoch 21/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5387 - accuracy: 0.7931
# Epoch 22/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5369 - accuracy: 0.7919
# Epoch 23/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5349 - accuracy: 0.7907
# Epoch 24/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5334 - accuracy: 0.7931
# Epoch 25/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5317 - accuracy: 0.7919
# Epoch 26/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5299 - accuracy: 0.7931
# Epoch 27/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5286 - accuracy: 0.7978
# Epoch 28/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5269 - accuracy: 0.7990
# Epoch 29/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5257 - accuracy: 0.7967
# Epoch 30/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5250 - accuracy: 0.7978
# Epoch 31/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5227 - accuracy: 0.7978
# Epoch 32/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5216 - accuracy: 0.7955
# Epoch 33/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5207 - accuracy: 0.7931
# Epoch 34/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5191 - accuracy: 0.7931
# Epoch 35/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5181 - accuracy: 0.7943
# Epoch 36/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5169 - accuracy: 0.7967
# Epoch 37/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5157 - accuracy: 0.7978
# Epoch 38/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5164 - accuracy: 0.8026
# Epoch 39/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5146 - accuracy: 0.7955
# Epoch 40/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5129 - accuracy: 0.7919
# Epoch 41/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5124 - accuracy: 0.7955
# Epoch 42/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5111 - accuracy: 0.7955
# Epoch 43/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5104 - accuracy: 0.7955
# Epoch 44/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5094 - accuracy: 0.7943
# Epoch 45/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5087 - accuracy: 0.7955
# Epoch 46/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.8002
# Epoch 47/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5067 - accuracy: 0.7943
# Epoch 48/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5060 - accuracy: 0.7943
# Epoch 49/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5051 - accuracy: 0.7967
# Epoch 50/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5043 - accuracy: 0.7955

# %%
y_pred = model.predict_classes(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4060\2480702830.py in <module>
# ----> 1 y_pred = model.predict_classes(X_test)
#       2 print(metrics.accuracy_score(y_test, y_pred))
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'
